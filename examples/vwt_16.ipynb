# %%
import procedural
import json
import os

master_path = "/home/kongsgaard/git/procedural-py/"
secret_path = os.path.join(master_path, "secrets")
data_path = os.path.join(master_path, "examples", "data")

# %%
user, password, url = procedural.utils.get_secrets(secret_path)
client = procedural.Client(url, user, password)
print(f"CLIENT: {client}")
# Out:
# CLIENT: http://localhost:8001 - Authenticated: Yes

# %%
project_name = "Jupyter Project"
project_number = 99
project = client.get_or_create("api/project/", {"name": project_name, "number": project_number})
project_id = project.get("uid")

print(f"PROJECT: {project_id[:8]}")
print(json.dumps(project, indent=4))
# Out:
# PROJECT: 733958e7
# {
#     "uid": "733958e7-cb8e-4c0b-94da-3d8d8e71b4de",
#     "name": "Jupyter Project",
#     "number": 99,
#     "cluster": "2a6812b0-9b95-4336-8819-26889a677b18",
#     "path": "/mnt/cluster/projects/99_jupyter-project",
#     "path_type": "name",
#     "company": "30eb91f9-d82c-4d1a-9370-9461ac531b92"
# }

# %%
task_name = "Jupyter VWT 16 Angles"
parent_task = client.get_or_create(
    f"api/project/{project.get('uid')}/task/",
    {"name": task_name},
    {"config": {
        "task_type": "parent",
        "case_dir": "foam"
    }
    })
parent_id = parent_task.get("uid")

print(f"PARENT TASK: {parent_id[:8]}")
print(json.dumps(parent_task, indent=4))
# Out:
# PARENT TASK: ee76c4d8
# {
#     "uid": "ee76c4d8-3a50-4a1a-a501-ddd24343068a",
#     "status": "waiting",
#     "started": null,
#     "stopped": null,
#     "created": "2020-08-26T08:50:43.090533",
#     "config": {
#         "case_dir": "foam",
#         "task_type": "parent"
#     },
#     "cluster_base_dir": "/mnt/cluster/projects/99_jupyter-project/jupyter-vwt-16-angles",
#     "parent": null,
#     "meta_json": {},
#     "project": "733958e7-cb8e-4c0b-94da-3d8d8e71b4de",
#     "name": "Jupyter VWT 16 Angles",
#     "dependent_on": null
# }

# %%
stl_path = os.path.join(data_path, "mesh_vwt", "cfdGeom.stl")
file_upload = client.update(f"api/task/{parent_id}/file/foam/constant/triSurface/cfdGeom.stl/",
                            files=open(stl_path, 'r').read())
print(f"UPLOADED FILE: {file_upload.get('file')}")
# Out:
# UPLOADED FILE: foam/constant/triSurface/cfdGeom.stl

# %%
write_mesh_path = os.path.join(data_path, "mesh_vwt", "write_mesh.json")
with open(write_mesh_path, 'r') as f:
    mesh_config = json.load(f)

payload = {"name": "Actions", "config": mesh_config, "parent": parent_id}
action_task = client.create(f"/api/project/{project_id}/task/", payload)
action_id = action_task.get("uid")

write_solution_path = os.path.join(data_path, "mesh_vwt", "write_solution.json")
with open(write_solution_path, 'r') as f:
    solution_config = json.load(f)

payload = {"name": "Actions", "status": "pending", "config": solution_config}
client.update(f"/api/project/{project_id}/task/{action_id}/", payload)

print(f"ACTION TASK: {action_id[:8]}")
print(json.dumps(action_task, indent=4))

configs = client.get(f"/api/task/{action_id}/config/")
print(f"TASK CONFIGS FOR ACTION TASK: {action_id[:8]}")
print(json.dumps(configs, indent=4))
# Out:
# ACTION TASK: 48b8017a
# {
#     "uid": "48b8017a-1a0d-4272-beaf-32222c08b6dc",
#     "status": "waiting",
#     "started": null,
#     "stopped": null,
#     "created": "2020-08-26T08:50:43.186481",
#     "config": {
#         "cmd": "cfd.io.tasks.write_mesh",
#         "case_dir": "foam",
#         "base_mesh": {
#             "type": "simpleBox",
#             "cell_size": 2,
#             "parameters": {
#                 "z0": "True",
#                 "square": "True"
#             },
#             "bounding_box": {
#                 "max": [
#                     35,
#                     35,
#                     24
#                 ],
#                 "min": [
#                     -35,
#                     -35,
#                     0
#                 ]
#             }
#         },
#         "task_type": "magpy",
#         "snappyhex_mesh": {
#             "surfaces": {
#                 "_269c2d39-4173-45a4-8f97-a21f3917d174": {
#                     "level": {
#                         "max": "2",
#                         "min": "2"
#                     }
#                 },
#                 "_29ceb925-bb98-4c8c-81c9-6af4f539bceb": {
#                     "level": {
#                         "max": "2",
#                         "min": "2"
#                     }
#                 },
#                 "_3d44c03a-88b0-45cc-a09c-3ebde502a6e3": {
#                     "level": {
#                         "max": "2",
#                         "min": "2"
#                     }
#                 },
#                 "_7ba22566-cd83-48ed-afdb-b24808f2d058": {
#                     "level": {
#                         "max": "2",
#                         "min": "2"
#                     }
#                 },
#                 "_865a46ee-2fb1-47ea-ba98-d340bbb07d07": {
#                     "level": {
#                         "max": "2",
#                         "min": "2"
#                     }
#                 }
#             },
#             "overrides": {
#                 "castellatedMeshControls": {
#                     "locationInMesh": [
#                         14.2847305471821,
#                         14.2847305471821,
#                         16.897621901891
#                     ]
#                 }
#             },
#             "default_surface": {
#                 "Plane": {
#                     "level": {
#                         "max": "3",
#                         "min": "3"
#                     }
#                 }
#             }
#         }
#     },
#     "cluster_base_dir": "/mnt/cluster/projects/99_jupyter-project/jupyter-vwt-16-angles",
#     "parent": {
#         "uid": "ee76c4d8-3a50-4a1a-a501-ddd24343068a",
#         "name": "Jupyter VWT 16 Angles"
#     },
#     "meta_json": {},
#     "project": "733958e7-cb8e-4c0b-94da-3d8d8e71b4de",
#     "name": "Actions",
#     "dependent_on": null
# }
# TASK CONFIGS FOR ACTION TASK: 48b8017a
# [
#     {
#         "uid": "1e45dd95-81b0-40a1-bbe1-6e898f7fce09",
#         "used": false,
#         "created": "2020-08-26T08:50:43.248050",
#         "started": null,
#         "stopped": null,
#         "config": {
#             "cmd": "cfd.io.tasks.write_solution",
#             "case_dir": "foam",
#             "solution": {
#                 "cpus": [
#                     2,
#                     2,
#                     1
#                 ],
#                 "angles": [
#                     0,
#                     22.5,
#                     45,
#                     67.5,
#                     90,
#                     112.5,
#                     135,
#                     157.5,
#                     180,
#                     202.5,
#                     225,
#                     247.5,
#                     270,
#                     292.5,
#                     315,
#                     337.5
#                 ],
#                 "solver": "simpleFoam",
#                 "case_type": "VirtualWindTunnel",
#                 "overrides": null,
#                 "iterations": {
#                     "run": 50,
#                     "init": 100
#                 },
#                 "boundary_conditions": {
#                     "MaxX": {
#                         "preset": "wall",
#                         "overrides": "wallSlip"
#                     },
#                     "MaxY": {
#                         "preset": "fixedVelocity",
#                         "overrides": {
#                             "U": "{ value uniform (0 -5 0); }"
#                         }
#                     },
#                     "MaxZ": {
#                         "preset": "wall",
#                         "overrides": "wallSlip"
#                     },
#                     "MinX": {
#                         "preset": "wall",
#                         "overrides": "wallSlip"
#                     },
#                     "MinY": {
#                         "preset": "fixedPressure"
#                     },
#                     "MinZ": {
#                         "preset": "wall",
#                         "overrides": "wallSlip"
#                     }
#                 }
#             },
#             "task_type": "magpy"
#         },
#         "task": "48b8017a-1a0d-4272-beaf-32222c08b6dc",
#         "priority": 1.0
#     },
#     {
#         "uid": "42f06870-fa49-43e6-b25f-209a707da337",
#         "used": false,
#         "created": "2020-08-26T08:50:43.208449",
#         "started": null,
#         "stopped": null,
#         "config": {
#             "cmd": "cfd.io.tasks.write_mesh",
#             "case_dir": "foam",
#             "base_mesh": {
#                 "type": "simpleBox",
#                 "cell_size": 2,
#                 "parameters": {
#                     "z0": "True",
#                     "square": "True"
#                 },
#                 "bounding_box": {
#                     "max": [
#                         35,
#                         35,
#                         24
#                     ],
#                     "min": [
#                         -35,
#                         -35,
#                         0
#                     ]
#                 }
#             },
#             "task_type": "magpy",
#             "snappyhex_mesh": {
#                 "surfaces": {
#                     "_269c2d39-4173-45a4-8f97-a21f3917d174": {
#                         "level": {
#                             "max": "2",
#                             "min": "2"
#                         }
#                     },
#                     "_29ceb925-bb98-4c8c-81c9-6af4f539bceb": {
#                         "level": {
#                             "max": "2",
#                             "min": "2"
#                         }
#                     },
#                     "_3d44c03a-88b0-45cc-a09c-3ebde502a6e3": {
#                         "level": {
#                             "max": "2",
#                             "min": "2"
#                         }
#                     },
#                     "_7ba22566-cd83-48ed-afdb-b24808f2d058": {
#                         "level": {
#                             "max": "2",
#                             "min": "2"
#                         }
#                     },
#                     "_865a46ee-2fb1-47ea-ba98-d340bbb07d07": {
#                         "level": {
#                             "max": "2",
#                             "min": "2"
#                         }
#                     }
#                 },
#                 "overrides": {
#                     "castellatedMeshControls": {
#                         "locationInMesh": [
#                             14.2847305471821,
#                             14.2847305471821,
#                             16.897621901891
#                         ]
#                     }
#                 },
#                 "default_surface": {
#                     "Plane": {
#                         "level": {
#                             "max": "3",
#                             "min": "3"
#                         }
#                     }
#                 }
#             }
#         },
#         "task": "48b8017a-1a0d-4272-beaf-32222c08b6dc",
#         "priority": 0.0
#     }
# ]

# %%
cpus = [2, 1, 1]
payload = {
    "name": "Mesh",
    "config": {
        "task_type": "cfd",
        "cmd": "pipeline",
        "cpus": cpus,
        "commands": [
            "blockMesh",
            "snappyHexMesh -overwrite",
            "reconstructParMesh -constant -mergeTol 1e-6",
            "!checkMesh -writeSets vtk"
        ]},
    "parent": parent_id,
    "dependent_on": action_id
}

mesh_task = client.create(f"/api/project/{project_id}/task/", payload)
mesh_id = mesh_task.get("uid")

print(f"MESH TASK: {mesh_id[:8]}")
print(json.dumps(mesh_task, indent=4))
# Out:
# MESH TASK: a19b29a1
# {
#     "uid": "a19b29a1-f313-47c2-acaa-99dbf1dc001f",
#     "status": "waiting",
#     "started": null,
#     "stopped": null,
#     "created": "2020-08-26T08:50:43.342186",
#     "config": {
#         "cmd": "pipeline",
#         "cpus": [
#             2,
#             1,
#             1
#         ],
#         "case_dir": "foam",
#         "commands": [
#             "blockMesh",
#             "snappyHexMesh -overwrite",
#             "reconstructParMesh -constant -mergeTol 1e-6",
#             "!checkMesh -writeSets vtk"
#         ],
#         "task_type": "cfd"
#     },
#     "cluster_base_dir": "/mnt/cluster/projects/99_jupyter-project/jupyter-vwt-16-angles",
#     "parent": {
#         "uid": "ee76c4d8-3a50-4a1a-a501-ddd24343068a",
#         "name": "Jupyter VWT 16 Angles"
#     },
#     "meta_json": {},
#     "project": "733958e7-cb8e-4c0b-94da-3d8d8e71b4de",
#     "name": "Mesh",
#     "dependent_on": {
#         "uid": "48b8017a-1a0d-4272-beaf-32222c08b6dc",
#         "name": "Actions"
#     }
# }

# %%
payload_vwt = {
    "name": "VWT",
    "config": {
        "task_type": "cfd",
        "cmd": "wind_tunnel",
        "commands": [
            0,
            22.5,
            45,
            67.5,
            90,
            112.5,
            135,
            157.5,
            180,
            202.5,
            225,
            247.5,
            270,
            292.5,
            315,
            337.5
        ],
        "cpus": cpus,
        "iterations": {
            "init": 100,
            "run": 50
        }
    },
    "parent": parent_id,
    "dependent_on": mesh_id
}

vwt_task = client.create(f"/api/project/{project_id}/task/", payload_vwt)
vwt_id = vwt_task.get("uid")

print(f"VWT TASK: {vwt_id[:8]}")
print(json.dumps(vwt_task, indent=4))
# Out:
# VWT TASK: 8272edf2
# {
#     "uid": "8272edf2-c509-4353-b26b-831bc9df782e",
#     "status": "waiting",
#     "started": null,
#     "stopped": null,
#     "created": "2020-08-26T08:50:43.423868",
#     "config": {
#         "cmd": "wind_tunnel",
#         "cpus": [
#             2,
#             1,
#             1
#         ],
#         "case_dir": "foam",
#         "commands": [
#             0,
#             22.5,
#             45,
#             67.5,
#             90,
#             112.5,
#             135,
#             157.5,
#             180,
#             202.5,
#             225,
#             247.5,
#             270,
#             292.5,
#             315,
#             337.5
#         ],
#         "task_type": "parent",
#         "iterations": {
#             "run": 50,
#             "init": 100
#         }
#     },
#     "cluster_base_dir": "/mnt/cluster/projects/99_jupyter-project/jupyter-vwt-16-angles",
#     "parent": {
#         "uid": "ee76c4d8-3a50-4a1a-a501-ddd24343068a",
#         "name": "Jupyter VWT 16 Angles"
#     },
#     "meta_json": {},
#     "project": "733958e7-cb8e-4c0b-94da-3d8d8e71b4de",
#     "name": "VWT",
#     "dependent_on": null
# }

# %%
payload = {
    "name": "Probing",
    "config": {
        "task_type": "cfd",
        "cmd": "pipeline",
        "commands": [
            "write_sample_set",
            "postProcess -fields '(U p)' -func internalCloud"
        ],
        "case_dir": "VWT/",
        "cpus": [1, 1, 1],
        "sets": [
            {"name": "set1",
             "points": [
                 [0, 0, 1],
                 [0, 1, 1]
             ]}
        ],
        "fields": ["U", "p"]
    },
    "parent": parent_id,
    "dependent_on": vwt_id
}
probe_task = client.create(f"/api/project/{project_id}/task/", payload)
probe_id = probe_task.get("uid")

print(f"PROBE TASK: {probe_id[:8]}")
print(json.dumps(probe_task, indent=4))
# Out:
# PROBE TASK: 49496053
# {
#     "uid": "49496053-1705-48ee-9aa0-35ece7cad841",
#     "status": "waiting",
#     "started": null,
#     "stopped": null,
#     "created": "2020-08-26T08:50:44.058242",
#     "config": {
#         "cmd": "pipeline",
#         "cpus": [
#             1,
#             1,
#             1
#         ],
#         "sets": [
#             {
#                 "name": "set1",
#                 "points": [
#                     [
#                         0,
#                         0,
#                         1
#                     ],
#                     [
#                         0,
#                         1,
#                         1
#                     ]
#                 ]
#             }
#         ],
#         "fields": [
#             "U",
#             "p"
#         ],
#         "case_dir": "VWT/",
#         "commands": [
#             "write_sample_set",
#             "postProcess -fields '(U p)' -func internalCloud"
#         ],
#         "task_type": "cfd"
#     },
#     "cluster_base_dir": "/mnt/cluster/projects/99_jupyter-project/jupyter-vwt-16-angles",
#     "parent": {
#         "uid": "ee76c4d8-3a50-4a1a-a501-ddd24343068a",
#         "name": "Jupyter VWT 16 Angles"
#     },
#     "meta_json": {},
#     "project": "733958e7-cb8e-4c0b-94da-3d8d8e71b4de",
#     "name": "Probing",
#     "dependent_on": {
#         "uid": "8272edf2-c509-4353-b26b-831bc9df782e",
#         "name": "VWT"
#     }
# }

# %%
#client.delete(f"api/project/{project_id}/task/{parent_id}/")
#client.delete(f"api/project/{project_id}/")
